# %% [markdown]
# <img src="img/itq.jpg" width="100"/>
# <br>
# *Cristopher Santander* <br>
# *30/03/2026* <br>
# https://github.com/DavidSantander0/machinelearnig-1.git

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Secundaria' 'Secundaria' 'Grado' 'Doctorado' 'Grado' 'Grado' 'Master'
#  'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Master' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Doctorado' 'Secundaria' 'Bachillerato' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Master' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Master'
#  'Secundaria' 'Grado' 'Doctorado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Master' 'Secundaria' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master'
#  'Secundaria' 'Grado' 'Grado' 'Master' 'Grado' 'Bachillerato' 'Master'
#  'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Doctorado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Master' 'Grado'
#  'Bachillerato' 'Master' 'Master' 'Grado' 'Bachillerato' 'Master'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Master' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Doctorado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Master' 'Master' 'Secundaria'
#  'Doctorado' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Master' 'Secundaria' 'Bachillerato' 'Secundaria' 'Master' 'Secundaria'
#  'Master' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Doctorado' 'Grado'
#  'Bachillerato' 'Master' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Secundaria' 'Master' 'Doctorado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Doctorado' 'Grado' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Master' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Master' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Master' 'Doctorado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Doctorado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Master' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado'
#  'Grado' 'Doctorado' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Doctorado' 'Bachillerato' 'Grado' 'Doctorado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Master'
#  'Doctorado' 'Master' 'Grado' 'Master' 'Bachillerato' 'Master'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Master' 'Secundaria' 'Doctorado' 'Bachillerato' 'Secundaria' 'Master'
#  'Master' 'Master' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Master'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Master' 'Master' 'Master' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información 
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1. COnvierto la lista a pd 
serie_estudios = pd.Series(nivel_estudios)

# %%
# 2. Calculamos la frecuencia absoluta
frecuencias_pd = serie_estudios.value_counts()
print("Frecuencias calculadas con Pandas:")
print(frecuencias_pd)
# Out:
# Frecuencias calculadas con Pandas:
# Bachillerato    172
# Grado           145
# Secundaria      110
# Master           52
# Doctorado        21
# Name: count, dtype: int64

# %%
#3 barras con pd 
plt.figure(figsize=(8, 5))
frecuencias_pd.plot(kind='bar', color='coral')
plt.title('Diagrama de Barras (Generado con Pandas)')
plt.xlabel('Nivel de estudios')
plt.ylabel('Frecuencia absoluta')
plt.show()

# %%
# 4. pie con pd
plt.figure(figsize=(6, 6))
frecuencias_pd.plot(kind='pie', autopct='%1.2f%%', cmap='Set3')
plt.title('Diagrama de Sectores (Generado con Pandas)')
plt.show()
